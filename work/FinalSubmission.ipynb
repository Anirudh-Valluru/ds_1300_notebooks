# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('../data/offenses-standardized.csv')
#print(ds)
#ds.drop(columns="row_hash")
#print(ds)

#data = ds["occurred_time"]
#print(data)

#for i in range(0,140550):
   # if data[i] == "NaN":
    #    data.drop(data[i])
        
#data = data.dropna()

#print(data)

#print(data[3837])


#nan = ""
#plot = data.plot(kind='bar',color='green')
#data=data.dropna()
#print(data)

# print(data[0])
# if data[0] != nan:
#     print("false")

#print(ds)


df =df.drop("row_hash", axis = 1)
df =df.drop("source", axis = 1)
#df =df.drop("agency_name", axis = 1)
df =df.drop("agency_ori", axis = 1)
df =df.drop("agency_incident_id", axis = 1)
df =df.drop("agency_name", axis = 1)
df =df.drop("top_ucr_classification", axis = 1)
df =df.drop("top_local_classification", axis = 1)
df =df.drop("nibrs_code", axis = 1)

df = df.dropna(subset=['occurred_time'])
# df = pd.to_datetime(df)

#datetime.reset_index();
df=df.reset_index()
df =df.drop("index", axis = 1)
df
# Out:
# /tmp/ipykernel_2701494/3253640463.py:5: DtypeWarning: Columns (7,19,21,22,24,25,27,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/offenses-standardized.csv')
#        occurred_date occurred_time offense_category   weapon firearm_ind  \
# 0         2017-05-31         15:59         HOMICIDE  FIREARM           Y
# 1         2017-05-31         23:32         HOMICIDE  FIREARM           Y
# 2         2017-05-30         00:35         HOMICIDE  FIREARM           Y
# 3         2017-05-30         15:04         HOMICIDE  FIREARM           Y
# 4         2017-05-29         23:38         HOMICIDE  FIREARM           Y
# ...              ...           ...              ...      ...         ...
# 136852    2007-12-18         20:55              NaN    OTHER           N
# 136853    2007-12-15         04:50              NaN    OTHER           N
# 136854    2007-12-18         17:00              NaN    OTHER           N
# ...

# %%
# data=datatime.str.split(':')
# print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 data=datatime.str.split(':')
#       2 print(data)
#
# NameError: name 'datatime' is not defined

# %%
df["hour"] = df["occurred_time"]
for i in range(0,136856):
        temp = df["occurred_time"][i]
        t=temp.split(":")
        df["hour"][i] = t[0]

print(df["hour"])
# Out:
# /tmp/ipykernel_2619993/3443154597.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["hour"][i] = t[0]
# 0           15
# 1           23
# 2           00
# 3           15
# 4           23
#           ...
# 136852      20
# 136853      04
# 136854      17
# 136855      04
# 136856    07:0
# Name: hour, Length: 136857, dtype: object

# %%
df = pd.read_csv('EditedByTimes.csv')
# Out:
# /tmp/ipykernel_2701494/525089044.py:1: DtypeWarning: Columns (4,13,15,16,18,19,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('EditedByTimes.csv')

# %%
df =df.drop("clearance_status", axis = 1)
df =df.drop("clearance_group", axis = 1)
df =df.drop("arrest_date", axis = 1)
df =df.drop("clearance_date", axis = 1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['occurred_date'] = pd.to_datetime(df['occurred_date'])

df['day'] = df['occurred_date'].dt.day
df['month'] = df['occurred_date'].dt.month
df['year'] = df['occurred_date'].dt.year

print(df)
# Out:
#         Unnamed: 0.1  Unnamed: 0 occurred_date occurred_time offense_category  \
# 0                  0           0    2017-05-31         15:59         HOMICIDE
# 1                  1           1    2017-05-31         23:32         HOMICIDE
# 2                  2           2    2017-05-30         00:35         HOMICIDE
# 3                  3           3    2017-05-30         15:04         HOMICIDE
# 4                  4           4    2017-05-29         23:38         HOMICIDE
# ...              ...         ...           ...           ...              ...
# 136852        136852      136852    2007-12-18         20:55              NaN
# 136853        136853      136853    2007-12-15         04:50              NaN
# 136854        136854      136854    2007-12-18         17:00              NaN
# 136855        136855      136855    2007-12-19         04:19              NaN
# 136856        136856      136856    2007-07-01          07:0              NaN
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt




df['occurred_date'] = pd.to_datetime(df['occurred_date'])


df['month'] = df['occurred_date'].dt.month

monthly_counts = df['month'].value_counts().sort_index()

plt.bar(monthly_counts.index, monthly_counts.values)
plt.xlabel('Month')
plt.ylabel('Incident Count')
plt.title('Monthly Incident Count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt




df['occurred_date'] = pd.to_datetime(df['occurred_date'])


df['day'] = df['occurred_date'].dt.day

daily_counts = df['day'].value_counts().sort_index()

plt.bar(daily_counts.index, daily_counts.values)
plt.xlabel('day')
plt.ylabel('Incident Count')
plt.title('Incident Count by Day of the Month')
plt.show()

# %%
for i in range(3675,140550):
    if data[i] != nan:
        temp = data[i]
        t=temp.split(":")
        data[i] = t[0]

print)
# Out:
# /tmp/ipykernel_2079383/2822242330.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = t[0]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
#       2     if data[i] != nan:
#       3         temp = data[i]
# ----> 4         t=temp.split(":")
#       5         data[i] = t[0]
#       7 print(data)
#
# AttributeError: 'float' object has no attribute 'split'

# %%
data[3675]

# %%
temp = data[3675]
temp
# Out:
# '15:59'

# %%
t= temp.split(":")
t[0]
# Out:
# '15'

# %%
data[3675] = t[0]

data[3675]
# Out:
# '15'

# %%
hours=df["hour"]
hours[136856] = "07"
hours=[int(i) for i in hours]
hours
#df["hour"]=hours
# Out:
# /tmp/ipykernel_2671724/1689511342.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hours[136856] = "07"
# [15,
#  23,
#  0,
#  15,
#  23,
#  19,
#  15,
#  12,
#  0,
#  0,
#  20,
#  4,
#  14,
#  23,
#  4,
#  22,
#  21,
#  9,
#  0,
#  22,
#  0,
#  3,
#  6,
#  5,
#  5,
#  22,
#  19,
#  16,
#  16,
#  13,
#  15,
#  14,
#  22,
#  23,
#  20,
#  19,
#  22,
#  17,
#  9,
#  21,
#  22,
#  14,
#  22,
#  20,
#  4,
#  4,
#  16,
#  13,
#  23,
#  15,
#  1,
#  19,
#  15,
#  0,
#  12,
#  17,
#  10,
#  22,
#  20,
#  22,
#  12,
#  21,
#  23,
#  5,
#  5,
#  15,
#  20,
#  12,
#  14,
#  14,
#  3,
#  13,
#  3,
#  17,
#  5,
#  15,
#  5,
#  5,
#  18,
#  20,
#  22,
#  22,
#  0,
#  17,
#  17,
#  16,
#  6,
#  17,
#  22,
#  15,
#  12,
#  15,
#  16,
#  9,
#  20,
#  14,
#  18,
#  20,
#  18,
#  16,
#  12,
#  0,
#  14,
# ...

# %%
counts = []


for i in range(25):

    count = hours.count(i)
    

    counts.append(count)


print(counts)
# Out:
# [7790, 8379, 8847, 8794, 8545, 7973, 7228, 6471, 5131, 3674, 2462, 1663, 1672, 2406, 3100, 3674, 4247, 5020, 5371, 5853, 6975, 7201, 7037, 7344, 0]

# %%
h = list(range(24))
counts.remove(0)
import matplotlib.pyplot as plt

plt.bar(h, counts)


plt.xlabel('Hour of the Day')
plt.ylabel('Crimes')
plt.title('Number of Crimes by Hour')


plt.show()

# %%
string_numbers=
numbers = []


for string_num in string_numbers:

    numeric_num = int(string_num)  

    

    numeric_numbers.append(numeric_num)


print(numeric_numbers)

#numbers = df["hour"]

counts = []


for i in range(25):
    count = numbers.count(i)
    

    counts.append(count)


print(counts)
# Out:
# /tmp/ipykernel_2619993/588002770.py:23: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. ser.count(level=1) should use ser.groupby(level=1).count().
#   count = numbers.count(i)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 21>()
#      20 # Iterate over each number from 0 to 24
#      21 for i in range(25):
#      22     # Count the occurrences of the current number in the 'numbers' list
# ---> 23     count = numbers.count(i)
#      25     # Append the count to the 'counts' list
#      26     counts.append(count)
#
# File /lustre/work/client/users/avalluru/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/core/series.py:1976, in Series.count(self, level)
#    1968     warnings.warn(
# ...
