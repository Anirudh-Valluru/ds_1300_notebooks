# %% [markdown]
# # Data Visualization

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.
#
# Upload a pdf of the plot to Canvas.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %config InlineBackend.figure_format ='retina'
df = pd.read_csv("../data/state_facts.tsv",delimiter='\t',skipfooter=14,engine='python')
df
# Out:
#                          State  Area_tot  Area_land  Area_water    Pop_2020  \
# 0                     Alabama     135767     131171        4597   5024279.0
# 1                      Alaska    1723337    1477953      245384    733391.0
# 2              American Samoa       1505        198        1307     49437.0
# 3                     Arizona     295234     294207        1026   7151502.0
# 4                    Arkansas     137732     134771        2961   3011524.0
# 5                  California     423967     403466       20501  39538223.0
# 6                    Colorado     269601     268431        1170   5773714.0
# 7                 Connecticut      14357      12542        1816   3605944.0
# 8                    Delaware       6446       5047        1399    989948.0
# 9        District of Columbia        177        158          19    689545.0
# 10                    Florida     170312     138887       31424  21538187.0
# ...

# %%
#df.plot.scatter('Area_land','Area_water',figsize=(10,10))
# df["Percent Area Land"] = 100*df["Area_land"]/df["Area_tot"]
# df["Percent Area Water"] = 100*df["Area_water"]/df["Area_tot"]
# df.plot.scatter('Percent Area Land','Percent Area Water',figsize=(10,10))
# df.plot.scatter('Percent Area Land','Area_tot',figsize=(10,10))
# df.plot.scatter('Percent Area Water','Area_tot',figsize=(10,10))
df["State Total Population Density"] = df["Pop_2020"]/df["Area_tot"]
# df.plot.scatter('Percent Area Land','Density',figsize=(10,10))
#cond = df["State"] == "District of Colombia"
#cond[9] = True
cond[12] = True
cond[37] = True
print(cond)
df = df.drop(df[cond].index)
# plt.title("Water Area in relation to total area")
df["Largest City Percent of Total Population"] = 100*df["city_1_pop"]/df["Pop_2020"]

#plot = df[["Largest City Percent of Total Population",'State Total Population Density']].plot(kind='bar',figsize=(10,10),colormap='cool')
#plot.set_xticklabels(df['USPS_code'])
plo=df.plot.scatter('Largest City Percent of Total Population','State Total Population Density',label="Largest Cities",title=("Largest city Percent of Total Population versus Total Population Density"),color="blue",figsize=(10,10))

#plt.x_label("
#matplotlib.pyplot.savefig(f)
plo.figure.savefig('04assignment.pdf')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 38    False
# 39    False
# 40    False
# 41    False
# 12     True
# 37     True
# Name: State, dtype: bool
# /tmp/ipykernel_2324810/1021923934.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df.drop(df[cond].index)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [65], in <cell line: 24>()
# ...

# %%
print("My plot shows the little correlation between the largest city in a state's population as a percent of the total state population alongside the state's average population density, and I found no correlation")
# Out:
# My plot shows the little correlation between the largest city in a state's population as a percent of the total state population alongside the state's average population density, and I found no correlation

# %%
print("I made it a bar graph because by state it would make more sense to keep things sepaeratied from one another. I made the plot about density and city population, because I thought a high population density might correlate to a high city population, as I thought of the east coast states with their large cities but small areas. There ended up being no correlation though. I removed guam and the mariana terretory because there's something wrong with their data.I made the color blue because I think blue can clearly display the data and provide a calming sense because of blue's correlation with the sky and sea.")
# Out:
# I made it a bar graph because by state it would make more sense to keep things sepaeratied from one another. I made the plot about density and city population, because I thought a high population density might correlate to a high city population, as I thought of the east coast states with their large cities but small areas. There ended up being no correlation though. I removed guam and the mariana terretory because there's something wrong with their data.I made the color blue because I think blue can clearly display the data and provide a calming sense because of blue's correlation with the sky and sea.
